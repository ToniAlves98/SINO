# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import cohen_kappa_score

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)
clf = LogisticRegression()
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 * 100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 * 100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 * 100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import cohen_kappa_score

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)
clf =  DecisionTreeClassifier(max_depth=5)
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 * 100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 * 100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 * 100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# Accuracy: 71.89 (+/- 10.29)
# precison: 78.35 (+/- 11.05)
# recall: 61.18 (+/- 26.66)
# roc_auc: 73.53 (+/- 19.70)
# f1: 67.52 (+/- 20.25)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)

scaler = StandardScaler()
scaler.fit(treino_x)
treino_x = scaler.transform(treino_x)
teste_x = scaler.transform(teste_x)

clf =  SVC()
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 *100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 *100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 *100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)
clf =  RandomForestClassifier(max_depth=5)
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 *100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 *100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 *100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy: 73.86 (+/- 6.12)
# precison: 80.89 (+/- 4.06)
# recall: 63.71 (+/- 12.32)
# roc_auc: 78.21 (+/- 4.05)
# f1: 71.73 (+/- 5.73)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import cross_val_score

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)
clf =  BernoulliNB()
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 *100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 *100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 *100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# Accuracy: 74.02 (+/- 3.60)
# precison: 76.87 (+/- 4.87)
# recall: 68.65 (+/- 7.76)
# roc_auc: 77.49 (+/- 3.99)
# f1: 72.44 (+/- 4.56)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)
clf =  MLPClassifier()
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 *100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 *100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 *100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)
clf = GradientBoostingClassifier(max_depth=5)
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')


print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 *100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 *100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 *100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# Accuracy: 65.48 (+/- 11.16)
# precison: 69.24 (+/- 15.98)
# recall: 60.12 (+/- 30.54)
# roc_auc: 71.31 (+/- 11.84)
# f1: 62.23 (+/- 22.21)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import ExtraTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import cohen_kappa_score

falso = pd.read_csv("falso.csv")
er = pd.read_csv("er.csv")

x = falso[["ind_nom_pens_ult1","ind_actividad_cliente","ind_nomina_ult1","ind_ctop_fin_ult1","tiprel_1mes","ind_tjcr_fin_ult1","ind_valo_fin_ult1","ind_fond_fin_ult1","ncodpers",
          "ind_ecue_fin_ult1","antiguedad","sexo","ind_dela_fin_ult1","ind_hip_fin_ult1","age","ind_reca_fin_ult1","indrel","pais_residencia","renta"]]
y = falso["ind_cco_fin_ult1"]

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.3,
                                                         stratify = y)
clf = ExtraTreeClassifier(max_depth=5)
clf.fit(treino_x, treino_y)

scores = cross_val_score(clf, x, y, cv=10)
precision = cross_val_score(clf, x, y, cv=10, scoring='precision')
recall = cross_val_score(clf, x, y, cv=10, scoring='recall')
roc_auc = cross_val_score(clf, x, y, cv=10, scoring='roc_auc')
f1 = cross_val_score(clf, x, y, cv=10, scoring='f1')



print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean() * 100, scores.std() * 2 * 100)) 
print("precison: %0.2f (+/- %0.2f)" % (precision.mean() * 100, precision.std() * 2 *100)) 
print("recall: %0.2f (+/- %0.2f)" % (recall.mean() * 100, recall.std() * 2 *100)) 
print("roc_auc: %0.2f (+/- %0.2f)" % (roc_auc.mean() * 100, roc_auc.std() * 2 *100))
print("f1: %0.2f (+/- %0.2f)" % (f1.mean() * 100, f1.std() * 2 * 100))
# Out:
# Accuracy: 70.54 (+/- 9.58)
# precison: 77.38 (+/- 9.95)
# recall: 62.87 (+/- 8.69)
# roc_auc: 75.24 (+/- 8.70)
# f1: 70.72 (+/- 5.32)
